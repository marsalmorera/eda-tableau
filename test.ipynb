# %%
import pandas as pd 
url = 'https://raw.githubusercontent.com/data-bootcamp-v4/data/main/we_fn_use_c_marketing_customer_value_analysis.csv'
df = pd.read_csv(url)

# %%
df.sample(10)
# Out:
#      Customer       State  Customer Lifetime Value Response  Coverage  \
# 3058  VN37592     Arizona              2860.864563       No     Basic
# 3876  BC47264  California              7684.887717       No  Extended
# 2861  LR37068      Oregon             11030.661480       No  Extended
# 7777  JH58573  California              7927.182997       No     Basic
# 8044  TU68427     Arizona              2649.658715       No     Basic
# 2729  IN91592  California              2810.671023       No     Basic
# 5309  VM66678      Oregon             14024.358390      Yes   Premium
# 4914  FX26050      Oregon             22712.023640       No     Basic
# 6765  QV65644      Oregon              6113.869984       No  Extended
# 3135  OC39051  California              6158.846901       No     Basic
#
#                  Education Effective To Date EmploymentStatus Gender  Income  \
# 3058  High School or Below            2/7/11         Employed      M   50332
# ...

# %%
df.to_csv('/Users/M.Morera_1/Documents/Ironhack/week_11/Labs_w11/lab-tableau/we_fn_use_c_marketing_customer_value_analysis.csv')

# %%
import os

# %%
os.getcwd()

# %%
# Better to save it into a excel file for tableau. 
df.to_excel('/Users/M.Morera_1/Documents/Ironhack/week_11/Labs_w11/lab-tableau/we_fn_use_c_marketing_customer_value_analysis.xlsx', index=False)
